# %%
from PIL import Image
img = Image.open('img\dog.jpg') #path relativo
#img = Image.open('C:/Users/ifoa/Desktop/prova_vscode/dog.jpg') path assoluto non usare mai
img.show()
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
def somma_due_numeri(a,b):
     print('questa funzione somma due numeri:')
     risultato = a + b 
     print('il risultato è  '+str(risultato)) # qui è costruito

# %%
somma_due_numeri(10,5)
# Out:
# questa funzione somma due numeri:
# il risultato è  15

# %%
def area_triangolo(a,b):
    area = (a*b)/2
    print("l'area del triangolo è " + str(area))

# %%
area_triangolo(5,2)
# Out:
# l'area del triangolo è 5.0

# %%
def area_rettangolo(a,b):
    area = a*b
    print("l'area del rettangolo è " +str(area))

# %%
area_rettangolo(10,3)
# Out:
# l'area del rettangolo è 30

# %%
def area_quadrato(a):
    area = a**2
    print("l'area del quadrato è " +str(area))

# %%
class Persona:
    def __init__(self,a,b):
        self.nome = a
        self.eta = b
    def double(self,x):
        return x*2
    def triple(self,x):
        return x*3
    def quadratoanni(self):
        return self.eta**2
pietro = Persona('pietro',28)

# %%
pietro.quadratoanni()
# Out:
# 784

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(667)
mydata = np.random.randint(0,101,(4,3))
mydata
# Out:
# array([[ 85,  15,  89],
#        [100,   3,  90],
#        [  2,  64,   0],
#        [ 36,  99,  47]])

# %%
myindex = ['CA', 'NY','AZ','TX']

# %%
mycolumns =['Jan','Feb','Mar']

# %%
df = pd.DataFrame(data=mydata)
df
# Out:
#      0   1   2
# 0   85  15  89
# 1  100   3  90
# 2    2  64   0
# 3   36  99  47

# %%
df = pd.DataFrame(data=mydata, index=myindex)
df
# Out:
#       0   1   2
# CA   85  15  89
# NY  100   3  90
# AZ    2  64   0
# TX   36  99  47

# %%
df = pd.DataFrame(data=mydata, index=myindex, columns=mycolumns)
df
# Out:
#     Jan  Feb  Mar
# CA   85   15   89
# NY  100    3   90
# AZ    2   64    0
# TX   36   99   47

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int32
#  1   Feb     4 non-null      int32
#  2   Mar     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
df.columns
# Out:
# Index(['Jan', 'Feb', 'Mar'], dtype='object')

# %%
df.index
# Out:
# Index(['CA', 'NY', 'AZ', 'TX'], dtype='object')
